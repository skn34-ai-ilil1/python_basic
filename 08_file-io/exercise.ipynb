# %%
f = open('C:/Users/playdata2/python_basic/08_file-io/frog_song.txt', 'w', encoding='utf-8')
f.write('개구리 소년 빰빠바 개구리 소년 빰빠바\n\n네가 울면 무지개 연못에 비가 온단다\n비바람 몰아쳐도 이겨내고\n일곱번 넘어져도 일어나~라\n울지말고 일어나 피리를 불어라\n\n<tool_call>릴리 개굴개굴 삘릴리리\n<tool_call>릴리 개굴개굴 삘릴리리\n\n무지개 연못에 웃음꽃 핀다.\n')
f.close()

# %%
f = open('C:\\Users\\playdata2\\python_basic\\08_file-io\\frog_song.txt', 'w', encoding='utf-8')
data = ['copy개구리 소년 빰빠바 개구리 소년 빰빠바\n\n', '네가 울면 무지개 연못에 비가 온단다\n', '비바람 몰아쳐도 이겨내고\n', '일곱번 넘어져도 일어나~라\n', '울지말고 일어나 피리를 불어라\n\n', '<tool_call>릴리 개굴개굴 삘릴리리\n', '<tool_call>릴리 개굴개굴 삘릴리리\n\n', '무지개 연못에 웃음꽃 핀다.\n']
f.writelines(data)
f.close()

# %%
f = open('frog_song.txt', 'r', encoding='utf-8')

data = f.read()
print(data)

f.close()
# Out:
# 개구리 소년 빰빠바 개구리 소년 빰빠바
#
# 네가 울면 무지개 연못에 비가 온단다
# 비바람 몰아쳐도 이겨내고
# 일곱번 넘어져도 일어나~라
# 울지말고 일어나 피리를 불어라
#
# <tool_call>릴리 개굴개굴 삘릴리리
# <tool_call>릴리 개굴개굴 삘릴리리
#
# 무지개 연못에 웃음꽃 핀다.

# %%
f = open('./frog_song.txt', 'r', encoding='utf-8')

line = f.readline()
print(line)

f.close()
# Out:
# 개구리 소년 빰빠바 개구리 소년 빰빠바

# %%
f = open('frog_song.txt', 'r', encoding='utf-8')

while True:
  line = f.readline()
  
  if not line:
    break
  print(line)
  
f.close()
# Out:
# 개구리 소년 빰빠바 개구리 소년 빰빠바
#
#
#
# 네가 울면 무지개 연못에 비가 온단다
#
# 비바람 몰아쳐도 이겨내고
#
# 일곱번 넘어져도 일어나~라
#
# 울지말고 일어나 피리를 불어라
#
#
#
# <tool_call>릴리 개굴개굴 삘릴리리
#
# <tool_call>릴리 개굴개굴 삘릴리리
#
#
#
# 무지개 연못에 웃음꽃 핀다.

# %%
f = open('frog_song.txt', 'r', encoding='utf-8')

line = f.readlines()

print(line)

f.close()
# Out:
# ['개구리 소년 빰빠바 개구리 소년 빰빠바\n', '\n', '네가 울면 무지개 연못에 비가 온단다\n', '비바람 몰아쳐도 이겨내고\n', '일곱번 넘어져도 일어나~라\n', '울지말고 일어나 피리를 불어라\n', '\n', '<tool_call>릴리 개굴개굴 삘릴리리\n', '<tool_call>릴리 개굴개굴 삘릴리리\n', '\n', '무지개 연못에 웃음꽃 핀다.\n']

# %%
f = open('frog_song.txt', 'r', encoding='utf-8')

lines = f.readlines()
for line in lines:
    print(line)

f.close()
# Out:
# 개구리 소년 빰빠바 개구리 소년 빰빠바
#
#
#
# 네가 울면 무지개 연못에 비가 온단다
#
# 비바람 몰아쳐도 이겨내고
#
# 일곱번 넘어져도 일어나~라
#
# 울지말고 일어나 피리를 불어라
#
#
#
# <tool_call>릴리 개굴개굴 삘릴리리
#
# <tool_call>릴리 개굴개굴 삘릴리리
#
#
#
# 무지개 연못에 웃음꽃 핀다.

# %%
f = open('frog_song.txt', 'r', encoding='utf-8')

for line in f:
    print(line)

f.close()
# Out:
# 개구리 소년 빰빠바 개구리 소년 빰빠바
#
#
#
# 네가 울면 무지개 연못에 비가 온단다
#
# 비바람 몰아쳐도 이겨내고
#
# 일곱번 넘어져도 일어나~라
#
# 울지말고 일어나 피리를 불어라
#
#
#
# <tool_call>릴리 개굴개굴 삘릴리리
#
# <tool_call>릴리 개굴개굴 삘릴리리
#
#
#
# 무지개 연못에 웃음꽃 핀다.

# %%
f1 = open('frog_song.txt', 'a', encoding='utf-8')
f1.write("노래끝")
f1.close()

f2 = open('frog_song.txt', 'r', encoding='utf-8')
data = f2.read()
print(data)
f2.close()
# Out:
# 개구리 소년 빰빠바 개구리 소년 빰빠바
#
# 네가 울면 무지개 연못에 비가 온단다
# 비바람 몰아쳐도 이겨내고
# 일곱번 넘어져도 일어나~라
# 울지말고 일어나 피리를 불어라
#
# <tool_call>릴리 개굴개굴 삘릴리리
# <tool_call>릴리 개굴개굴 삘릴리리
#
# 무지개 연못에 웃음꽃 핀다.
# 노래끝노래끝

# %%
f1 = open('frog_song.txt', 'a', encoding='utf-8')
f1.write("51515151")
f1.write(str(516515151))
f1.close()

f2 = open('frog_song.txt', 'r', encoding='utf-8')
data = f2.read()
print(data)
f2.close()
# Out:
# 개구리 소년 빰빠바 개구리 소년 빰빠바
#
# 네가 울면 무지개 연못에 비가 온단다
# 비바람 몰아쳐도 이겨내고
# 일곱번 넘어져도 일어나~라
# 울지말고 일어나 피리를 불어라
#
# <tool_call>릴리 개굴개굴 삘릴리리
# <tool_call>릴리 개굴개굴 삘릴리리
#
# 무지개 연못에 웃음꽃 핀다.
# 노래끝노래끝5151515151515151516515151

# %%
with open("newFile2.txt", "w", encoding='utf-8') as f:
    f.write("Life is too short, you need python")

# %%
import os
os.makedirs("test", exist_ok=True)
